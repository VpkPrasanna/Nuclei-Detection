# %%
import os 
import sys
import random
import warnings


import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

from tqdm import tqdm
from itertools import chain
from skimage.io import imread ,imshow,imread_collection,concatenate_images
from skimage.transform import resize 
from skimage.morphology import label

#Keras import
from keras.models import Model,load_model
from keras.layers import Input
from keras.layers.core import Dropout,Lambda
from keras.layers.convolutional import Conv2D,Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping,ModelCheckpoint
from keras import backend as K
import tensorflow as tf

#some Parameters
IMG_WIDTH = 128
IMG_HEIGHT = 128
IMG_CHANNELS = 3

TRAIN_PATH = 'nuclei_datasets/stage1_train/'
TEST_PATH = 'nuclei_datasets/stage1_test/'



warnings.filterwarnings('ignore',category=UserWarning,module ='skimage')
seed = 42
random.seed = seed
np.random.seed = seed

# %%
#get train and test IDs

train_ids = next(os.walk(Train_path))[1]
test_ids = next(os.walk(Test_path))[1]

# %%
 #Get and resize train images and masks
X_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
Y_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
print('Getting and resizing train images and masks ... ')
sys.stdout.flush()
for n, id_ in tqdm(enumerate(train_ids), total=len(train_ids)):
    path = TRAIN_PATH + id_
    img = imread(path + '/images/' + id_ + '.png')[:,:,:IMG_CHANNELS]
    img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    X_train[n] = img
    mask = np.zeros((IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
    for mask_file in next(os.walk(path + '/masks/'))[2]:
        mask_ = imread(path + '/masks/' + mask_file)
        mask_ = np.expand_dims(resize(mask_, (IMG_HEIGHT, IMG_WIDTH), mode='constant', 
                                      preserve_range=True), axis=-1)
        mask = np.maximum(mask, mask_)
    Y_train[n] = mask

# Get and resize test images
X_test = np.zeros((len(test_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
sizes_test = []
print('Getting and resizing test images ... ')
sys.stdout.flush()
for n, id_ in tqdm(enumerate(test_ids), total=len(test_ids)):
    path = TEST_PATH + id_
    img = imread(path + '/images/' + id_ + '.png')[:,:,:IMG_CHANNELS]
    sizes_test.append([img.shape[0], img.shape[1]])
    img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    X_test[n] = img

print('Done!')
# Out:
# Getting and resizing train images and masks ...
# 100%|██████████| 670/670 [02:33<00:00,  3.25it/s]
# Getting and resizing test images ...
# 100%|██████████| 65/65 [00:01<00:00, 33.86it/s]
# Done!

# %%
# Check if training data looks all right
ix = random.randint(0, len(train_ids))
imshow(X_train[ix])
plt.show()
imshow(np.squeeze(Y_train[ix]))
plt.show()

# %%
# Define IoU metric
def mean_iou(y_true, y_pred):
    prec = []
    for t in np.arange(0.5, 1.0, 0.05):
        y_pred_ = tf.to_int32(y_pred > t)
        score, up_opt = tf.metrics.mean_iou(y_true, y_pred_, 2)
        K.get_session().run(tf.local_variables_initializer())
        with tf.control_dependencies([up_opt]):
            score = tf.identity(score)
        prec.append(score)
    return K.mean(K.stack(prec), axis=0)

# %%
# Build U-Net model
inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
s = Lambda(lambda x: x / 255) (inputs)

c1 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (s)
c1 = Dropout(0.1) (c1)
c1 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c1)
p1 = MaxPooling2D((2, 2)) (c1)

c2 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p1)
c2 = Dropout(0.1) (c2)
c2 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c2)
p2 = MaxPooling2D((2, 2)) (c2)

c3 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p2)
c3 = Dropout(0.2) (c3)
c3 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c3)
p3 = MaxPooling2D((2, 2)) (c3)

c4 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p3)
c4 = Dropout(0.2) (c4)
c4 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c4)
p4 = MaxPooling2D(pool_size=(2, 2)) (c4)

c5 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p4)
c5 = Dropout(0.3) (c5)
c5 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c5)

u6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same') (c5)
u6 = concatenate([u6, c4])
c6 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u6)
c6 = Dropout(0.2) (c6)
c6 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c6)

u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same') (c6)
u7 = concatenate([u7, c3])
c7 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u7)
c7 = Dropout(0.2) (c7)
c7 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c7)

u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same') (c7)
u8 = concatenate([u8, c2])
c8 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u8)
c8 = Dropout(0.1) (c8)
c8 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c8)

u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same') (c8)
u9 = concatenate([u9, c1], axis=3)
c9 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u9)
c9 = Dropout(0.1) (c9)
c9 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c9)

outputs = Conv2D(1, (1, 1), activation='sigmoid') (c9)

model = Model(inputs=[inputs], outputs=[outputs])
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=[mean_iou])
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 128, 128, 3)  0
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 128, 128, 3)  0           input_3[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 128, 128, 16) 448         lambda_3[0][0]
# __________________________________________________________________________________________________
# dropout_19 (Dropout)            (None, 128, 128, 16) 0           conv2d_39[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 128, 128, 16) 2320        dropout_19[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 64, 64, 16)   0           conv2d_40[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 64, 64, 32)   4640        max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# dropout_20 (Dropout)            (None, 64, 64, 32)   0           conv2d_41[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 64, 64, 32)   9248        dropout_20[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 32, 32, 32)   0           conv2d_42[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 32, 32, 64)   18496       max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# dropout_21 (Dropout)            (None, 32, 32, 64)   0           conv2d_43[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 32, 32, 64)   36928       dropout_21[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 16, 16, 64)   0           conv2d_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 16, 16, 128)  73856       max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# dropout_22 (Dropout)            (None, 16, 16, 128)  0           conv2d_45[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 16, 16, 128)  147584      dropout_22[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 8, 8, 128)    0           conv2d_46[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 8, 8, 256)    295168      max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# dropout_23 (Dropout)            (None, 8, 8, 256)    0           conv2d_47[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 8, 8, 256)    590080      dropout_23[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_9 (Conv2DTrans (None, 16, 16, 128)  131200      conv2d_48[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 16, 16, 256)  0           conv2d_transpose_9[0][0]
#                                                                  conv2d_46[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 16, 16, 128)  295040      concatenate_9[0][0]
# __________________________________________________________________________________________________
# dropout_24 (Dropout)            (None, 16, 16, 128)  0           conv2d_49[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 16, 16, 128)  147584      dropout_24[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_10 (Conv2DTran (None, 32, 32, 64)   32832       conv2d_50[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 32, 32, 128)  0           conv2d_transpose_10[0][0]
#                                                                  conv2d_44[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 32, 32, 64)   73792       concatenate_10[0][0]
# __________________________________________________________________________________________________
# dropout_25 (Dropout)            (None, 32, 32, 64)   0           conv2d_51[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 32, 32, 64)   36928       dropout_25[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_11 (Conv2DTran (None, 64, 64, 32)   8224        conv2d_52[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 64, 64, 64)   0           conv2d_transpose_11[0][0]
#                                                                  conv2d_42[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 64, 64, 32)   18464       concatenate_11[0][0]
# __________________________________________________________________________________________________
# dropout_26 (Dropout)            (None, 64, 64, 32)   0           conv2d_53[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 64, 64, 32)   9248        dropout_26[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_12 (Conv2DTran (None, 128, 128, 16) 2064        conv2d_54[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 128, 128, 32) 0           conv2d_transpose_12[0][0]
#                                                                  conv2d_40[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 128, 128, 16) 4624        concatenate_12[0][0]
# __________________________________________________________________________________________________
# dropout_27 (Dropout)            (None, 128, 128, 16) 0           conv2d_55[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 128, 128, 16) 2320        dropout_27[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 128, 128, 1)  17          conv2d_56[0][0]
# ==================================================================================================
# Total params: 1,941,105
# Trainable params: 1,941,105
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Fit model
earlystopper = EarlyStopping(patience=5, verbose=1)
checkpointer = ModelCheckpoint('model-dsbowl2018-1.h5', verbose=1, save_best_only=True)
results = model.fit(X_train, Y_train, validation_split=0.1, batch_size=16, epochs=50, 
                    callbacks=[earlystopper, checkpointer])
# Out:
# Train on 603 samples, validate on 67 samples
# Epoch 1/50
# 603/603 [==============================] - 186s 309ms/step - loss: 0.3147 - mean_iou: 0.4495 - val_loss: 0.1541 - val_mean_iou: 0.5379
#
# Epoch 00001: val_loss improved from inf to 0.15413, saving model to model-dsbowl2018-1.h5
# Epoch 2/50
# 603/603 [==============================] - 174s 288ms/step - loss: 0.1621 - mean_iou: 0.5948 - val_loss: 0.1259 - val_mean_iou: 0.6333
#
# Epoch 00002: val_loss improved from 0.15413 to 0.12593, saving model to model-dsbowl2018-1.h5
# Epoch 3/50
# 603/603 [==============================] - 131s 217ms/step - loss: 0.1300 - mean_iou: 0.6561 - val_loss: 0.0942 - val_mean_iou: 0.6798
#
# Epoch 00003: val_loss improved from 0.12593 to 0.09419, saving model to model-dsbowl2018-1.h5
# Epoch 4/50
# 603/603 [==============================] - 122s 203ms/step - loss: 0.1187 - mean_iou: 0.6962 - val_loss: 0.0854 - val_mean_iou: 0.7092
#
# Epoch 00004: val_loss improved from 0.09419 to 0.08539, saving model to model-dsbowl2018-1.h5
# Epoch 5/50
# 603/603 [==============================] - 122s 203ms/step - loss: 0.1067 - mean_iou: 0.7213 - val_loss: 0.0780 - val_mean_iou: 0.7307
#
# Epoch 00005: val_loss improved from 0.08539 to 0.07797, saving model to model-dsbowl2018-1.h5
# Epoch 6/50
# 603/603 [==============================] - 122s 203ms/step - loss: 0.0982 - mean_iou: 0.7390 - val_loss: 0.0857 - val_mean_iou: 0.7468
#
# Epoch 00006: val_loss did not improve from 0.07797
# Epoch 7/50
# 603/603 [==============================] - 122s 202ms/step - loss: 0.0932 - mean_iou: 0.7534 - val_loss: 0.0726 - val_mean_iou: 0.7594
#
# Epoch 00007: val_loss improved from 0.07797 to 0.07256, saving model to model-dsbowl2018-1.h5
# Epoch 8/50
# 603/603 [==============================] - 122s 202ms/step - loss: 0.0904 - mean_iou: 0.7648 - val_loss: 0.0741 - val_mean_iou: 0.7694
#
# Epoch 00008: val_loss did not improve from 0.07256
# Epoch 9/50
# 603/603 [==============================] - 122s 202ms/step - loss: 0.0870 - mean_iou: 0.7738 - val_loss: 0.0676 - val_mean_iou: 0.7779
#
# Epoch 00009: val_loss improved from 0.07256 to 0.06763, saving model to model-dsbowl2018-1.h5
# Epoch 10/50
# 603/603 [==============================] - 122s 202ms/step - loss: 0.0872 - mean_iou: 0.7813 - val_loss: 0.0690 - val_mean_iou: 0.7845
#
# Epoch 00010: val_loss did not improve from 0.06763
# Epoch 11/50
# 603/603 [==============================] - 122s 202ms/step - loss: 0.0832 - mean_iou: 0.7876 - val_loss: 0.0764 - val_mean_iou: 0.7905
#
# Epoch 00011: val_loss did not improve from 0.06763
# Epoch 12/50
# 603/603 [==============================] - 123s 204ms/step - loss: 0.0828 - mean_iou: 0.7927 - val_loss: 0.0674 - val_mean_iou: 0.7954
#
# Epoch 00012: val_loss improved from 0.06763 to 0.06739, saving model to model-dsbowl2018-1.h5
# Epoch 13/50
# 603/603 [==============================] - 124s 205ms/step - loss: 0.0794 - mean_iou: 0.7977 - val_loss: 0.0705 - val_mean_iou: 0.7999
#
# Epoch 00013: val_loss did not improve from 0.06739
# Epoch 14/50
# 603/603 [==============================] - 9982s 17s/step - loss: 0.0816 - mean_iou: 0.8019 - val_loss: 0.0648 - val_mean_iou: 0.8036
#
# Epoch 00014: val_loss improved from 0.06739 to 0.06482, saving model to model-dsbowl2018-1.h5
# Epoch 15/50
# 603/603 [==============================] - 127s 211ms/step - loss: 0.0772 - mean_iou: 0.8053 - val_loss: 0.0669 - val_mean_iou: 0.8071
#
# Epoch 00015: val_loss did not improve from 0.06482
# Epoch 16/50
# 603/603 [==============================] - 122s 202ms/step - loss: 0.0767 - mean_iou: 0.8087 - val_loss: 0.0652 - val_mean_iou: 0.8104
#
# Epoch 00016: val_loss did not improve from 0.06482
# Epoch 17/50
# 603/603 [==============================] - 122s 203ms/step - loss: 0.0744 - mean_iou: 0.8119 - val_loss: 0.0652 - val_mean_iou: 0.8135
#
# Epoch 00017: val_loss did not improve from 0.06482
# Epoch 18/50
# 603/603 [==============================] - 121s 201ms/step - loss: 0.0767 - mean_iou: 0.8148 - val_loss: 0.0639 - val_mean_iou: 0.8160
#
# Epoch 00018: val_loss improved from 0.06482 to 0.06386, saving model to model-dsbowl2018-1.h5
# Epoch 19/50
# 603/603 [==============================] - 123s 203ms/step - loss: 0.0763 - mean_iou: 0.8171 - val_loss: 0.0638 - val_mean_iou: 0.8183
#
# Epoch 00019: val_loss improved from 0.06386 to 0.06379, saving model to model-dsbowl2018-1.h5
# Epoch 20/50
# 603/603 [==============================] - 143s 237ms/step - loss: 0.0760 - mean_iou: 0.8194 - val_loss: 0.0733 - val_mean_iou: 0.8203
#
# Epoch 00020: val_loss did not improve from 0.06379
# Epoch 21/50
# 603/603 [==============================] - 145s 241ms/step - loss: 0.0780 - mean_iou: 0.8213 - val_loss: 0.0631 - val_mean_iou: 0.8221
#
# Epoch 00021: val_loss improved from 0.06379 to 0.06315, saving model to model-dsbowl2018-1.h5
# Epoch 22/50
# 603/603 [==============================] - 142s 236ms/step - loss: 0.0725 - mean_iou: 0.8230 - val_loss: 0.0655 - val_mean_iou: 0.8240
#
# Epoch 00022: val_loss did not improve from 0.06315
# Epoch 23/50
# 603/603 [==============================] - 141s 233ms/step - loss: 0.0717 - mean_iou: 0.8251 - val_loss: 0.0602 - val_mean_iou: 0.8259
#
# Epoch 00023: val_loss improved from 0.06315 to 0.06015, saving model to model-dsbowl2018-1.h5
# Epoch 24/50
# 603/603 [==============================] - 147s 243ms/step - loss: 0.0714 - mean_iou: 0.8268 - val_loss: 0.0593 - val_mean_iou: 0.8276
#
# Epoch 00024: val_loss improved from 0.06015 to 0.05933, saving model to model-dsbowl2018-1.h5
# Epoch 25/50
# 603/603 [==============================] - 146s 242ms/step - loss: 0.0692 - mean_iou: 0.8285 - val_loss: 0.0591 - val_mean_iou: 0.8293
#
# Epoch 00025: val_loss improved from 0.05933 to 0.05911, saving model to model-dsbowl2018-1.h5
# Epoch 26/50
# 603/603 [==============================] - 141s 233ms/step - loss: 0.0705 - mean_iou: 0.8301 - val_loss: 0.0599 - val_mean_iou: 0.8308
#
# Epoch 00026: val_loss did not improve from 0.05911
# Epoch 27/50
# 603/603 [==============================] - 133s 220ms/step - loss: 0.0684 - mean_iou: 0.8314 - val_loss: 0.0575 - val_mean_iou: 0.8322
#
# Epoch 00027: val_loss improved from 0.05911 to 0.05749, saving model to model-dsbowl2018-1.h5
# Epoch 28/50
# 603/603 [==============================] - 142s 235ms/step - loss: 0.0677 - mean_iou: 0.8330 - val_loss: 0.0591 - val_mean_iou: 0.8337
#
# Epoch 00028: val_loss did not improve from 0.05749
# Epoch 29/50
# 603/603 [==============================] - 159s 264ms/step - loss: 0.0673 - mean_iou: 0.8343 - val_loss: 0.0591 - val_mean_iou: 0.8349
#
# Epoch 00029: val_loss did not improve from 0.05749
# Epoch 30/50
# 603/603 [==============================] - 159s 263ms/step - loss: 0.0664 - mean_iou: 0.8356 - val_loss: 0.0591 - val_mean_iou: 0.8362
#
# Epoch 00030: val_loss did not improve from 0.05749
# Epoch 31/50
# 603/603 [==============================] - 152s 252ms/step - loss: 0.0654 - mean_iou: 0.8368 - val_loss: 0.0581 - val_mean_iou: 0.8375
#
# Epoch 00031: val_loss did not improve from 0.05749
# Epoch 32/50
# 603/603 [==============================] - 150s 249ms/step - loss: 0.0640 - mean_iou: 0.8382 - val_loss: 0.0606 - val_mean_iou: 0.8388
#
# Epoch 00032: val_loss did not improve from 0.05749
# Epoch 00032: early stopping

# %%
# Predict on train, val and test
model = load_model('model-dsbowl2018-1.h5', custom_objects={'mean_iou': mean_iou})
preds_train = model.predict(X_train[:int(X_train.shape[0]*0.9)], verbose=1)
preds_val = model.predict(X_train[int(X_train.shape[0]*0.9):], verbose=1)
preds_test = model.predict(X_test, verbose=1)

# Threshold predictions
preds_train_t = (preds_train > 0.5).astype(np.uint8)
preds_val_t = (preds_val > 0.5).astype(np.uint8)
preds_test_t = (preds_test > 0.5).astype(np.uint8)

# Create list of upsampled test masks
preds_test_upsampled = []
for i in range(len(preds_test)):
    preds_test_upsampled.append(resize(np.squeeze(preds_test[i]), 
                                       (sizes_test[i][0], sizes_test[i][1]), 
                                       mode='constant', preserve_range=True))
# Out:
# 603/603 [==============================] - 32s 53ms/step
# 67/67 [==============================] - 3s 48ms/step
# 65/65 [==============================] - 3s 48ms/step

# %%
# Perform a sanity check on some random training samples
ix = random.randint(0, len(preds_train_t))
imshow(X_train[ix])
plt.show()
imshow(np.squeeze(Y_train[ix]))
plt.show()
imshow(np.squeeze(preds_train_t[ix]))
plt.show()

# %%
# Perform a sanity check on some random validation samples
ix = random.randint(0, len(preds_val_t))
imshow(X_train[int(X_train.shape[0]*0.9):][ix])
plt.show()
imshow(np.squeeze(Y_train[int(Y_train.shape[0]*0.9):][ix]))
plt.show()
imshow(np.squeeze(preds_val_t[ix]))
plt.show()
